# %%
import numpy as np

# %%
from numpy import genfromtxt
my_data = genfromtxt('./data/series/1.csv', delimiter=',')
my_data1 = genfromtxt('./data/series/2.csv', delimiter=',')
my_data2 = genfromtxt('./data/series/3.csv', delimiter=',')
my_data3 = genfromtxt('./data/series/4.csv', delimiter=',')
my_data4 = genfromtxt('./data/series/5.csv', delimiter=',')
my_data5 = genfromtxt('./data/series/6.csv', delimiter=',')
my_data6 = genfromtxt('./data/series/7.csv', delimiter=',')
my_data7 = genfromtxt('./data/series/8.csv', delimiter=',')
my_data8 = genfromtxt('./data/series/9.csv', delimiter=',')
# my_data9 = genfromtxt('./data/series/2.csv', delimiter=',')

# %%
my_data.shape
# Out:
# (1000, 2)

# %%
final = np.concatenate([my_data, my_data1, my_data2, my_data3, my_data4, my_data5, my_data6, my_data7, my_data8])

# %%
X_embedded = final

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# sns settings
sns.set(rc={'figure.figsize':(15,15)})

# colors
palette = sns.color_palette("bright", 1)

# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], palette=palette)
plt.title('t-SNE with no Labels')
plt.savefig("./t-sne_covid19.png")
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(15, 15)})
palette = sns.hls_palette(20, l=.4, s=.9)
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y_pred, legend='full', palette=palette)
plt.title('t-SNE with Kmeans Labels')
plt.savefig("./improved_cluster_tsne.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-08b44e065114> in <module>
#       4 sns.set(rc={'figure.figsize':(15, 15)})
#       5 palette = sns.hls_palette(20, l=.4, s=.9)
# ----> 6 sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y_pred, legend='full', palette=palette)
#       7 plt.title('t-SNE with Kmeans Labels')
#       8 plt.savefig("./improved_cluster_tsne.png")
#
# NameError: name 'y_pred' is not defined
